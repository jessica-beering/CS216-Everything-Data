# %%
# Required Python Machine learning Packages
import pandas as pd
import numpy as np
# For preprocessing the data
from sklearn.preprocessing import Imputer
from sklearn import preprocessing
# To split the dataset into train and test datasets
from sklearn.cross_validation import train_test_split
# To model the Gaussian Navie Bayes classifier
from sklearn.naive_bayes import GaussianNB
# To calculate the accuracy score of the model
from sklearn.metrics import accuracy_score

import csv

# !pip3 install pandas
# Out:
# /home/vcm/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Collecting pandas
#   Using cached https://files.pythonhosted.org/packages/99/0a/37930bbee7a06bb5ce7e12f7970b29a17a49605d0b08a72dee7ab76135bb/pandas-0.22.0-cp35-cp35m-manylinux1_x86_64.whl
# Collecting python-dateutil>=2 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/0c/57/19f3a65bcf6d5be570ee8c35a5398496e10a0ddcbc95393b2d17f86aaaf8/python_dateutil-2.7.2-py2.py3-none-any.whl
# Collecting numpy>=1.9.0 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/7b/61/11b05cc37ccdaabad89f04dbdc2a02905cf6de6f9b05816dba843beed328/numpy-1.14.3-cp35-cp35m-manylinux1_x86_64.whl
# Collecting pytz>=2011k (from pandas)
#   Using cached https://files.pythonhosted.org/packages/dc/83/15f7833b70d3e067ca91467ca245bae0f6fe56ddc7451aa0dc5606b120f2/pytz-2018.4-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2->pandas)
#   Using cached https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Installing collected packages: six, python-dateutil, numpy, pytz, pandas
# Successfully installed numpy-1.14.2 pandas-0.22.0 python-dateutil-2.7.2 pytz-2018.3 six-1.11.0
# You are using pip version 8.1.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#Data Import -- new csv file only columns of interest 
with open('popFeaturesZeroOneTwo.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    
    #headers = next(reader) #list of colomn names 
    
    #print headers
    
    df = pd.read_csv(csvfile)
  
    #imageCol = df[' num_imgs']
    
    #print imageCol
    
    headers = [' num_imgs', ' num_videos', ' data_channel_is_lifestyle', 
               ' data_channel_is_entertainment', ' data_channel_is_bus', 
               ' data_channel_is_socmed', ' data_channel_is_tech', 
               ' data_channel_is_world', ' weekday_is_monday', 
               ' weekday_is_tuesday', ' weekday_is_wednesday', 
               ' weekday_is_thursday', ' weekday_is_friday', 
               ' weekday_is_saturday', ' weekday_is_sunday', ' shares', ' pop shares']

# Data PreProcessing - make copy of original data frame

    df_copy = df

# Basic Stats

    df_copy.describe(include= 'all')

# Data Slicing 

    features = df_copy.values[:, :2] # 16 = number of columns - 1
    #print features[:10]
    target = df_copy.values[:, 18]
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.75, random_state = None)
    
# The features_train & target_train consists of training data and 
# the features_test & target_test consists of testing data.

# Gaussian Naive Bayes Implementation

    clf = GaussianNB()
    clf.fit(features_train, target_train)
    target_pred = clf.predict(features_test)
    
# Accuracy of our Gaussian Naive Bayes model

    visualScore = accuracy_score(target_test, target_pred, normalize = True)
    print visualScore
# Out:
# 0.4941964135517949

# %%
#Data Import -- new csv file only columns of interest 
with open('popFeaturesZeroOneTwo.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    
    #headers = next(reader) #list of colomn names 
    
    #print headers
    
    df = pd.read_csv(csvfile)
  
    #imageCol = df[' num_imgs']
    
    #print imageCol
    
    headers = [' num_imgs', ' num_videos', ' data_channel_is_lifestyle', 
               ' data_channel_is_entertainment', ' data_channel_is_bus', 
               ' data_channel_is_socmed', ' data_channel_is_tech', 
               ' data_channel_is_world', ' weekday_is_monday', 
               ' weekday_is_tuesday', ' weekday_is_wednesday', 
               ' weekday_is_thursday', ' weekday_is_friday', 
               ' weekday_is_saturday', ' weekday_is_sunday', ' shares', ' pop shares']

# Data PreProcessing - make copy of original data frame

    df_copy = df

# Basic Stats

    df_copy.describe(include= 'all')

# Data Slicing 

    features = df_copy.values[:, 2:8] # 16 = number of columns - 1
    #print features[:10]
    target = df_copy.values[:, 18]
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.75, random_state = None)
    
# The features_train & target_train consists of training data and 
# the features_test & target_test consists of testing data.

# Gaussian Naive Bayes Implementation

    clf = GaussianNB()
    clf.fit(features_train, target_train)
    target_pred = clf.predict(features_test)
    
# Accuracy of our Gaussian Naive Bayes model

    dataChannelScore = accuracy_score(target_test, target_pred, normalize = True)
    print dataChannelScore
# Out:
# 0.43531944958449686

# %%
#Data Import -- new csv file only columns of interest 
with open('popFeaturesZeroOneTwo.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    
    #headers = next(reader) #list of colomn names 
    
    #print headers
    
    df = pd.read_csv(csvfile)
  
    #imageCol = df[' num_imgs']
    
    #print imageCol
    
    headers = [' num_imgs', ' num_videos', ' data_channel_is_lifestyle', 
               ' data_channel_is_entertainment', ' data_channel_is_bus', 
               ' data_channel_is_socmed', ' data_channel_is_tech', 
               ' data_channel_is_world', ' weekday_is_monday', 
               ' weekday_is_tuesday', ' weekday_is_wednesday', 
               ' weekday_is_thursday', ' weekday_is_friday', 
               ' weekday_is_saturday', ' weekday_is_sunday', ' shares', ' pop shares']

# Data PreProcessing - make copy of original data frame

    df_copy = df

# Basic Stats

    df_copy.describe(include= 'all')

# Data Slicing 

    features = df_copy.values[:, 8:15] # 16 = number of columns - 1
    #print features[:10]
    target = df_copy.values[:, 18]
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.75, random_state = None)
    
# The features_train & target_train consists of training data and 
# the features_test & target_test consists of testing data.

# Gaussian Naive Bayes Implementation

    clf = GaussianNB()
    clf.fit(features_train, target_train)
    target_pred = clf.predict(features_test)
    
# Accuracy of our Gaussian Naive Bayes model

    dayWeekScore = accuracy_score(target_test, target_pred, normalize = True)
    print dayWeekScore
# Out:
# 0.3255727887494533

# %%
#Data Import -- new csv file only columns of interest 
with open('popFeaturesZeroOneTwo.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    
    #headers = next(reader) #list of colomn names 
    
    #print headers
    
    df = pd.read_csv(csvfile)
  
    #imageCol = df[' num_imgs']
    
    #print imageCol
    
    headers = [' num_imgs', ' num_videos', ' data_channel_is_lifestyle', 
               ' data_channel_is_entertainment', ' data_channel_is_bus', 
               ' data_channel_is_socmed', ' data_channel_is_tech', 
               ' data_channel_is_world', ' weekday_is_monday', 
               ' weekday_is_tuesday', ' weekday_is_wednesday', 
               ' weekday_is_thursday', ' weekday_is_friday', 
               ' weekday_is_saturday', ' weekday_is_sunday', ' shares', ' pop shares']

# Data PreProcessing - make copy of original data frame

    df_copy = df

# Basic Stats

    df_copy.describe(include= 'all')

# Data Slicing 

    features = df_copy.values[:, 15:17] # 16 = number of columns - 1
    #print features[:10]
    target = df_copy.values[:, 18]
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.33, random_state = None)
    
# The features_train & target_train consists of training data and 
# the features_test & target_test consists of testing data.

# Gaussian Naive Bayes Implementation

    clf = GaussianNB()
    clf.fit(features_train, target_train)
    target_pred = clf.predict(features_test)

# Accuracy of our Gaussian Naive Bayes model

    trendingWordsScore = accuracy_score(target_test, target_pred, normalize = True)
    print trendingWordsScore
# Out:
# 0.5051231075087934

# %%
#Data Import -- new csv file only columns of interest 
with open('popFeaturesZeroOneTwo.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    
    #headers = next(reader) #list of colomn names 
    
    #print headers
    
    df = pd.read_csv(csvfile)
  
    #imageCol = df[' num_imgs']
    
    #print imageCol
    
    headers = [' num_imgs', ' num_videos', ' data_channel_is_lifestyle', 
               ' data_channel_is_entertainment', ' data_channel_is_bus', 
               ' data_channel_is_socmed', ' data_channel_is_tech', 
               ' data_channel_is_world', ' weekday_is_monday', 
               ' weekday_is_tuesday', ' weekday_is_wednesday', 
               ' weekday_is_thursday', ' weekday_is_friday', 
               ' weekday_is_saturday', ' weekday_is_sunday', ' shares', ' pop shares']

# Data PreProcessing - make copy of original data frame

    df_copy = df

# Basic Stats

    df_copy.describe(include= 'all')

# Data Slicing 

    features = df_copy.values[:, 17:18] # 16 = number of columns - 1
    #print features[:10]
    target = df_copy.values[:, 18]
    features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.75, random_state = None)
    
# The features_train & target_train consists of training data and 
# the features_test & target_test consists of testing data.

# Gaussian Naive Bayes Implementation

    clf = GaussianNB()
    clf.fit(features_train, target_train)
    target_pred = clf.predict(features_test)
    
# Accuracy of our Gaussian Naive Bayes model

    ariScore = accuracy_score(target_test, target_pred, normalize = True)
    print ariScore
# Out:
# 0.5062073142011237
